# %%
import pandas as pd
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import QuantileTransformer, LabelEncoder

# %%
data = pd.read_csv(r"IP-files\TCP-based\ACK-Flood-simple-1.csv")
print(data.shape)
# Out:
# (820000, 347)

# %%
null_cols = ['fwd_packets_count', 'fwd_total_payload_bytes', 'payload_bytes_mode', 'fwd_payload_bytes_max', 'fwd_payload_bytes_min', 'packets_IAT_mean']
files = r"IP-files\TCP-based\Connection-Test-hping3.csv"
data = pd.read_csv(files)

import matplotlib.pyplot as plt
import seaborn as sns

print("=== TỶ LỆ DỮ LIỆU BỊ THIẾU (NULL) ===")
print(data[null_cols].isnull().sum() / len(data) * 100)
print("\n")

#dropna
for col in null_cols:
    data = data.dropna(subset=[col])

data.to_csv(r"IP-files\TCP-based\Connection-Test-hping3-dropna.csv", index=False)
# Out:
# === TỶ LỆ DỮ LIỆU BỊ THIẾU (NULL) ===
# fwd_packets_count          0.000191
# fwd_total_payload_bytes    0.000191
# payload_bytes_mode         0.000191
# fwd_payload_bytes_max      0.000191
# fwd_payload_bytes_min      0.000191
# packets_IAT_mean           0.000191
# dtype: float64

# %%
links = [
    r"IP-files\TCP-based\ACK-Flood-hping3.csv",
    r"IP-files\TCP-based\ACK-Flood-simple-1.csv",
    r"IP-files\TCP-based\ACK-Flood-simple-2.csv",
    r"IP-files\TCP-based\ACK-Flood-simple.csv",
    r"IP-files\TCP-based\Connection-MHDDoS.csv",
    r"IP-files\TCP-based\Connection-Test-hping3-dropna.csv",
    r"IP-files\TCP-based\NULL-TCP-Xerox.csv", 
    r"IP-files\TCP-based\SYN-Flood-MHDDoS-1.csv",
    r"IP-files\TCP-based\SYN-Flood-MHDDoS-2.csv",
    r"IP-files\TCP-based\SYN-Flood-MHDDoS.csv",
    r"IP-files\TCP-based\SYN-Flood-Simple.csv",
    r"IP-files\TCP-based\SYN-PSH-hping3-1.csv",
    r"IP-files\TCP-based\SYN-PSH-hping3-2.csv",
    r"IP-files\TCP-based\SYN-PSH-hping3.csv",
    r"IP-files\TCP-based\SYN-PSH-URG-hping3.csv",
    r"IP-files\TCP-based\TCP-Flood-FiberFox.csv",
    r"IP-files\TCP-based\TCP-Flood-MHDDoS.csv",
    r"IP-files\TCP-based\TCP-Slowloris-hping3-1.csv",
    r"IP-files\TCP-based\TCP-Slowloris-hping3.csv",
    r"IP-files\TCP-based\TCP-Flood-Xerox.csv",
]

# %%
fill_0 = ['fwd_skewness_header_bytes', 'fwd_payload_bytes_skewness', 'fwd_payload_bytes_cov',
    'payload_bytes_skewness', 'payload_bytes_cov', 'skewness_header_bytes',
    'fwd_segment_size_skewness', 'segment_size_skewness', 'bwd_packets_IAT_skewness',
    'bwd_packets_IAT_cov', 'fwd_packets_IAT_skewness', 'packets_IAT_skewness',
    'skewness_fwd_header_bytes_delta_len', 'cov_fwd_header_bytes_delta_len',
    'skewness_payload_bytes_delta_len', 'cov_payload_bytes_delta_len',
    'skewness_header_bytes_delta_len', 'cov_header_bytes_delta_len',
    'skewness_fwd_payload_bytes_delta_len', 'cov_fwd_payload_bytes_delta_len',
    'skewness_packets_delta_len', 'cov_packets_delta_len',
    'skewness_fwd_packets_delta_len', 'cov_fwd_packets_delta_len',
    'skewness_fwd_packets_delta_time', 'skewness_packets_delta_time',
     'bwd_payload_bytes_skewness', 'bwd_payload_bytes_cov',
     'skewness_bwd_payload_bytes_delta_len', 'cov_bwd_payload_bytes_delta_len',
     'bwd_skewness_header_bytes', 'bwd_segment_size_skewness',
     'skewness_bwd_header_bytes_delta_len', 'cov_bwd_header_bytes_delta_len',
     'skewness_bwd_packets_delta_len', 'cov_bwd_packets_delta_len',
     'skewness_bwd_packets_delta_time', 'fwd_packets_IAT_cov'
    ]

# %%
os.makedirs(r"ip-files-fillna-tcp", exist_ok=True)
for link in links:
    data = pd.read_csv(link)
    fill_0 = [col for col in data.columns if ("skewness" in col.lower() or "cov" in col.lower()) and data[col].isnull().sum() >0]
    data[fill_0] = data[fill_0].fillna(0)
    cols_has_null = [col for col in data.columns if data[col].isnull().sum() >0]
    if len(cols_has_null) > 0:
        print(f"Warning: {link} still has null values in columns: {cols_has_null}")
    else:
        data.to_csv(link.replace(r"IP-files\TCP-based", r"ip-files-fillna-tcp").replace(".csv", "-fillna.csv"), index=False)
        print(f"{link} has been processed and saved without null values.")
# Out:
# IP-files\TCP-based\ACK-Flood-hping3.csv has been processed and saved without null values.
# IP-files\TCP-based\ACK-Flood-simple-1.csv has been processed and saved without null values.
# IP-files\TCP-based\ACK-Flood-simple-2.csv has been processed and saved without null values.
# IP-files\TCP-based\ACK-Flood-simple.csv has been processed and saved without null values.
# IP-files\TCP-based\Connection-MHDDoS.csv has been processed and saved without null values.
# IP-files\TCP-based\Connection-Test-hping3-dropna.csv has been processed and saved without null values.
# IP-files\TCP-based\NULL-TCP-Xerox.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-Flood-MHDDoS-1.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-Flood-MHDDoS-2.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-Flood-MHDDoS.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-Flood-Simple.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-PSH-hping3-1.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-PSH-hping3-2.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-PSH-hping3.csv has been processed and saved without null values.
# IP-files\TCP-based\SYN-PSH-URG-hping3.csv has been processed and saved without null values.
# IP-files\TCP-based\TCP-Flood-FiberFox.csv has been processed and saved without null values.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19180\1712043167.py:3: DtypeWarning: Columns (237,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(link)
# IP-files\TCP-based\TCP-Flood-MHDDoS.csv has been processed and saved without null values.
# IP-files\TCP-based\TCP-Slowloris-hping3-1.csv has been processed and saved without null values.
# IP-files\TCP-based\TCP-Slowloris-hping3.csv has been processed and saved without null values.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19180\1712043167.py:3: DtypeWarning: Columns (237,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(link)
# IP-files\TCP-based\TCP-Flood-Xerox.csv has been processed and saved without null values.

# %%
processed_links = [link.replace(r"IP-files\TCP-based", r"ip-files-fillna-tcp").replace(".csv", "-fillna.csv") for link in links]

# %%
def reduce_mem_usage(df, filename=""):
    """
    Tự động quét qua các cột và ép kiểu dữ liệu xuống để tiết kiệm RAM.
    Đồng thời đưa các cột bị lỗi object/mixed types dứt khoát về dạng string.
    """
    start_mem = df.memory_usage().sum() / 1024**2
    
    for col in df.columns:
        col_type = df[col].dtype
        
        # Chỉ xử lý các cột dạng số (không phải chuỗi/object)
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            
            # Xử lý số Nguyên (Integer)
            if pd.api.types.is_integer_dtype(col_type):
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            
            # Xử lý số Thực (Float) - Ta ép về float32 là tốt nhất cho LSTM/CNN
            elif pd.api.types.is_float_dtype(col_type):
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            # Sửa Fix lỗi Parquet ArrowTypeError cho các cột object lẫn lộn
            # Ép ép dứt khoát tất cả object về kiểu chuỗi (string) để pyarrow không crash
            df[col] = df[col].astype(str)
                    
    end_mem = df.memory_usage().sum() / 1024**2
    if filename:
        print(f'[{filename}] Giảm bộ nhớ: {start_mem:.2f} MB -> {end_mem:.2f} MB (Tiết kiệm {100 * (start_mem - end_mem) / start_mem:.1f}%)')
    
    return df

# %%
def process_chunk_based_split():
    train_list = []
    valid_list = []
    test_list = []
    num_chunks = 3

    # 1. Đọc các file và chia 10 khối
    for link in processed_links:
        print(f"[{link}] Reading and processing...")
        df = pd.read_csv(link)
        df = df.sort_values(by = "timestamp").reset_index(drop = True)
        df["timestamp_num"] =  pd.to_datetime(df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
        df.sort_values(by="timestamp_num", inplace= True)
        df.drop(columns=["timestamp_num"], inplace=True)

        # 2. Xử lý ép kiểu dữ liệu giảm RAM
        df = reduce_mem_usage(df, filename=link)

        # 3. Chia Cách 1: 10 chunks cố định, lấy 65-15-20 mỗi chunk
        chunk_size = len(df) // num_chunks
        
        for i in range(num_chunks):
            start_idx = i * chunk_size
            end_idx = (i + 1) * chunk_size if i < num_chunks - 1 else len(df)
            chunk = df.iloc[start_idx:end_idx]
            
            train_bound = int(len(chunk) * 0.65)
            valid_bound = train_bound + int(len(chunk) * 0.15)
            
            train_list.append(chunk.iloc[:train_bound])
            valid_list.append(chunk.iloc[train_bound:valid_bound])
            test_list.append(chunk.iloc[valid_bound:])

    print("--- Đang gộp các DataFrames lại... ---")
    train_df = pd.concat(train_list, ignore_index=True)
    valid_df = pd.concat(valid_list, ignore_index=True)
    test_df = pd.concat(test_list, ignore_index=True)

    # 4. Ép 2 cột thời lượng về numeric, giá trị không hợp lệ -> 0.0
    time_cols = ["delta_start", "handshake_duration"]
    for df in [train_df, valid_df, test_df]:
        for col in time_cols:
            if col in df.columns:
                df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0.0)

    # 5. Thay thế Inf bằng max, -Inf bằng min trên bản thân TỪNG DataFrame
    def resolve_infinity(df_target):
        num_cols = df_target.select_dtypes(include=[np.number]).columns
        for col in num_cols:
            has_inf_pos = (df_target[col] == np.inf).any()
            has_inf_neg = (df_target[col] == -np.inf).any()
            
            if has_inf_pos or has_inf_neg:
                max_val = df_target.loc[df_target[col] != np.inf, col].max()
                min_val = df_target.loc[df_target[col] != -np.inf, col].min()
                
                # Biện pháp phòng hờ: Nếu toàn tập là inf dẫn đến max là NaN
                if pd.isna(max_val): max_val = 0.0
                if pd.isna(min_val): min_val = 0.0
                
                df_target[col] = df_target[col].replace(np.inf, max_val)
                df_target[col] = df_target[col].replace(-np.inf, min_val)
        return df_target
        
    print("--- Đang xử lý các giá trị Infinity... ---")
    train_df = resolve_infinity(train_df)
    valid_df = resolve_infinity(valid_df)
    test_df = resolve_infinity(test_df)

    # 7. Bỏ các cột có <= 1 giá trị ở train_df rồi áp dụng lên valid và test
    print("--- Loại bỏ các cột mang giá trị hằng số (chỉ có 1 unique value)... ---")
    constant_cols = [col for col in train_df.columns if train_df[col].nunique() <= 1]
    train_df.drop(columns=constant_cols, inplace=True, errors='ignore')
    valid_df.drop(columns=constant_cols, inplace=True, errors='ignore')
    test_df.drop(columns=constant_cols, inplace=True, errors='ignore')

    # Trích các cột numerical để chuẩn bị scale
    numeric_cols = train_df.select_dtypes(include=[np.number]).columns.tolist()
    if "label" in numeric_cols:
        numeric_cols.remove("label")

    # 6. Dùng QuantileTransformer (Fit trên Train -> Transform cho 3 tập)
    print("--- Scale dữ liệu bằng QuantileTransformer... ---")
    scaler = QuantileTransformer(output_distribution= "normal", random_state=42)
    train_df[numeric_cols] = scaler.fit_transform(train_df[numeric_cols])
    valid_df[numeric_cols] = scaler.transform(valid_df[numeric_cols])
    test_df[numeric_cols] = scaler.transform(test_df[numeric_cols])

    # 8. Label Encoding
    if "label" in train_df.columns:
        print("--- Đang Label Encoding... ---")
        le = LabelEncoder()
        train_df["label"] = le.fit_transform(train_df["label"].astype(str))
        
        # Đề phòng Valid/Test có nhãn không tồn tại trong Train (rất hiếm vì đã chia chu kỳ)
        known_classes = set(le.classes_)
        def safe_transform_labels(series):
            return le.transform(series.astype(str).map(lambda x: x if x in known_classes else le.classes_[0]))

        valid_df["label"] = safe_transform_labels(valid_df["label"])
        test_df["label"] = safe_transform_labels(test_df["label"])

    # 9. Lưu vào folder chunk-based-split theo định dạng .parquet
    save_folder = os.path.join("final_data_tcp_based", "chunk-based-split-3")
    os.makedirs(save_folder, exist_ok=True)
    
    print("--- Đang lưu DataFrames sang định dạng Parquet... ---")
    train_df.to_parquet(os.path.join(save_folder, "train_df_prepared.parquet"), index=False)
    valid_df.to_parquet(os.path.join(save_folder, "valid_df_prepared.parquet"), index=False)
    test_df.to_parquet(os.path.join(save_folder, "test_df_prepared.parquet"), index=False)
    
    print(f"\n[Hoàn tất] File đã được lưu thành công trong: {save_folder}")
    print(f"Kích thước Train: {train_df.shape}")
    print(f"Kích thước Valid: {valid_df.shape}")
    print(f"Kích thước Test:  {test_df.shape}")

# %%
process_chunk_based_split()
# Out:
# [ip-files-fillna-tcp\ACK-Flood-hping3-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\ACK-Flood-hping3-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 911.83 MB (Tiết kiệm 58.0%)
# [ip-files-fillna-tcp\ACK-Flood-simple-1-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\ACK-Flood-simple-1-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 914.96 MB (Tiết kiệm 57.9%)
# [ip-files-fillna-tcp\ACK-Flood-simple-2-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\ACK-Flood-simple-2-fillna.csv] Giảm bộ nhớ: 1069.70 MB -> 482.83 MB (Tiết kiệm 54.9%)
# [ip-files-fillna-tcp\ACK-Flood-simple-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\ACK-Flood-simple-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 914.96 MB (Tiết kiệm 57.9%)
# [ip-files-fillna-tcp\Connection-MHDDoS-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\Connection-MHDDoS-fillna.csv] Giảm bộ nhớ: 611.11 MB -> 288.43 MB (Tiết kiệm 52.8%)
# [ip-files-fillna-tcp\Connection-Test-hping3-dropna-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\Connection-Test-hping3-dropna-fillna.csv] Giảm bộ nhớ: 1387.77 MB -> 629.90 MB (Tiết kiệm 54.6%)
# [ip-files-fillna-tcp\NULL-TCP-Xerox-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\NULL-TCP-Xerox-fillna.csv] Giảm bộ nhớ: 813.25 MB -> 381.72 MB (Tiết kiệm 53.1%)
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-1-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-1-fillna.csv] Giảm bộ nhớ: 2117.92 MB -> 978.85 MB (Tiết kiệm 53.8%)
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-2-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-2-fillna.csv] Giảm bộ nhớ: 589.89 MB -> 268.38 MB (Tiết kiệm 54.5%)
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-Flood-MHDDoS-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 954.84 MB (Tiết kiệm 56.0%)
# [ip-files-fillna-tcp\SYN-Flood-Simple-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-Flood-Simple-fillna.csv] Giảm bộ nhớ: 2431.13 MB -> 1074.57 MB (Tiết kiệm 55.8%)
# [ip-files-fillna-tcp\SYN-PSH-hping3-1-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-PSH-hping3-1-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 822.68 MB (Tiết kiệm 62.1%)
# [ip-files-fillna-tcp\SYN-PSH-hping3-2-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-PSH-hping3-2-fillna.csv] Giảm bộ nhớ: 1742.71 MB -> 794.14 MB (Tiết kiệm 54.4%)
# [ip-files-fillna-tcp\SYN-PSH-hping3-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-PSH-hping3-fillna.csv] Giảm bộ nhớ: 2170.87 MB -> 917.30 MB (Tiết kiệm 57.7%)
# [ip-files-fillna-tcp\SYN-PSH-URG-hping3-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\SYN-PSH-URG-hping3-fillna.csv] Giảm bộ nhớ: 2064.97 MB -> 882.97 MB (Tiết kiệm 57.2%)
# [ip-files-fillna-tcp\TCP-Flood-FiberFox-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\TCP-Flood-FiberFox-fillna.csv] Giảm bộ nhớ: 17.30 MB -> 7.75 MB (Tiết kiệm 55.2%)
# [ip-files-fillna-tcp\TCP-Flood-MHDDoS-fillna.csv] Reading and processing...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19180\2581233313.py:10: DtypeWarning: Columns (237,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(link)
# [ip-files-fillna-tcp\TCP-Flood-MHDDoS-fillna.csv] Giảm bộ nhớ: 11.99 MB -> 5.36 MB (Tiết kiệm 55.3%)
# [ip-files-fillna-tcp\TCP-Slowloris-hping3-1-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\TCP-Slowloris-hping3-1-fillna.csv] Giảm bộ nhớ: 822.54 MB -> 372.16 MB (Tiết kiệm 54.8%)
# [ip-files-fillna-tcp\TCP-Slowloris-hping3-fillna.csv] Reading and processing...
# [ip-files-fillna-tcp\TCP-Slowloris-hping3-fillna.csv] Giảm bộ nhớ: 2143.90 MB -> 983.14 MB (Tiết kiệm 54.1%)
# [ip-files-fillna-tcp\TCP-Flood-Xerox-fillna.csv] Reading and processing...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19180\2581233313.py:10: DtypeWarning: Columns (237,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(link)
# [ip-files-fillna-tcp\TCP-Flood-Xerox-fillna.csv] Giảm bộ nhớ: 229.19 MB -> 109.15 MB (Tiết kiệm 52.4%)
# --- Đang gộp các DataFrames lại... ---
# --- Đang xử lý các giá trị Infinity... ---
# --- Loại bỏ các cột mang giá trị hằng số (chỉ có 1 unique value)... ---
# --- Scale dữ liệu bằng QuantileTransformer... ---
# --- Đang Label Encoding... ---
# --- Đang lưu DataFrames sang định dạng Parquet... ---
#
# [Hoàn tất] File đã được lưu thành công trong: final_data_tcp_based\chunk-based-split-3
# Kích thước Train: (7139032, 330)
# Kích thước Valid: (1647443, 330)
# Kích thước Test:  (2196695, 330)
